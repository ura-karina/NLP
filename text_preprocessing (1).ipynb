# %%
text = open("/content/NLP.txt").read()
print(text[0:100], '...')
# Out:
# Анализ саундтреков из аккаунтов пользователей позволяет сделать выводы об их музыкальных предпочтени ...

# %% [markdown]
# ## Sentence tokenization

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Split into sentence
nltk.download('punkt_tab')
sentences = sent_tokenize(text)
print("Sentence Tokenization:")
for idx, sentence in enumerate(sentences[0:10]):
    print(f"{idx+1}: {sentence}")
# Out:
# Sentence Tokenization:
# 1: Анализ саундтреков из аккаунтов пользователей позволяет сделать выводы об их музыкальных предпочтениях.
# 2: А используя наработанные коррелянты можно судить о характере пользователя.
# 3: Например, считается: экстраверты в целом чаще слушают музыку и их музыкальные предпочтения более разнообразны, однако они более склонны к поп, хип-хоп, сценической и современной-хитовой музыке.
# 4: Экстраверты мало слушают музыку, которая «старше их по возрасту»: т.е.
# 5: экстраверт 1990 года рождения практически не будет слушать музыку, вышедшую раньше своего рождения.
# 6: У интровертов это наблюдается в разы чаще.
# 7: Экстраверты чаще слушают музыку в качестве фона.
# 8: При этом, - доказано, что экстраверты по сравнению с интровертами, чаще слушают музыку со словами, чем без слов.
# 9: Интроверты практически не слушают современные хиты из топ-10, а начинают их слушать (и покупать) спустя почти год после их выхода.
# 10: «Доброжелательные» люди имеют четко ограниченный набор любимых песен и предпочитают не расширять этот список.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# Split into tokens
print("\nWord Tokenization:")
tokenized_text = []
for idx, sentence in enumerate(sentences):
    words = word_tokenize(sentence)
    tokenized_text.append(words)
    print(f"Sentence {idx+1} Words: {words}")
# Out:
# Word Tokenization:
# Sentence 1 Words: ['Анализ', 'саундтреков', 'из', 'аккаунтов', 'пользователей', 'позволяет', 'сделать', 'выводы', 'об', 'их', 'музыкальных', 'предпочтениях', '.']
# Sentence 2 Words: ['А', 'используя', 'наработанные', 'коррелянты', 'можно', 'судить', 'о', 'характере', 'пользователя', '.']
# Sentence 3 Words: ['Например', ',', 'считается', ':', 'экстраверты', 'в', 'целом', 'чаще', 'слушают', 'музыку', 'и', 'их', 'музыкальные', 'предпочтения', 'более', 'разнообразны', ',', 'однако', 'они', 'более', 'склонны', 'к', 'поп', ',', 'хип-хоп', ',', 'сценической', 'и', 'современной-хитовой', 'музыке', '.']
# Sentence 4 Words: ['Экстраверты', 'мало', 'слушают', 'музыку', ',', 'которая', '«', 'старше', 'их', 'по', 'возрасту', '»', ':', 'т.е', '.']
# Sentence 5 Words: ['экстраверт', '1990', 'года', 'рождения', 'практически', 'не', 'будет', 'слушать', 'музыку', ',', 'вышедшую', 'раньше', 'своего', 'рождения', '.']
# Sentence 6 Words: ['У', 'интровертов', 'это', 'наблюдается', 'в', 'разы', 'чаще', '.']
# Sentence 7 Words: ['Экстраверты', 'чаще', 'слушают', 'музыку', 'в', 'качестве', 'фона', '.']
# Sentence 8 Words: ['При', 'этом', ',', '-', 'доказано', ',', 'что', 'экстраверты', 'по', 'сравнению', 'с', 'интровертами', ',', 'чаще', 'слушают', 'музыку', 'со', 'словами', ',', 'чем', 'без', 'слов', '.']
# Sentence 9 Words: ['Интроверты', 'практически', 'не', 'слушают', 'современные', 'хиты', 'из', 'топ-10', ',', 'а', 'начинают', 'их', 'слушать', '(', 'и', 'покупать', ')', 'спустя', 'почти', 'год', 'после', 'их', 'выхода', '.']
# Sentence 10 Words: ['«', 'Доброжелательные', '»', 'люди', 'имеют', 'четко', 'ограниченный', 'набор', 'любимых', 'песен', 'и', 'предпочитают', 'не', 'расширять', 'этот', 'список', '.']
# Sentence 11 Words: ['Кстати', ',', 'так', 'же', 'поступают', 'и', 'люди', 'с', 'невысокими', 'показателями', '«', 'открытости', 'опыту', '»', '.']
# Sentence 12 Words: ['Доброжелательные', 'люди', 'достоверно', 'чаще', 'предпочитают', 'спокойную', ',', 'ретро', 'и', 'релакс-музыку', ',', 'а', 'менее', 'доброжелательные', '–', 'панк', 'и', 'рэп', '.']
# Sentence 13 Words: ['Удивительно', ',', 'но', 'шансон', ',', 'в', 'русском', 'понимании', 'этого', 'направления', ',', 'оказался', ',', 'что', 'больше', 'связан', 'с', 'закрытостью', 'к', 'опыту', ',', 'а', 'не', 'к', 'сниженной', 'доброжелательности', '.']
# Sentence 14 Words: ['«', 'Добросовестность', '»', 'незначительно', 'коррелирует', 'с', 'хитами', '90-х', 'песен', 'на', 'своем', 'языке', ',', 'сниженная', 'добросовестность', 'слабо', 'коррелирует', 'с', 'прослушиванием', 'рэпа', 'и', 'отсутствием', 'музыкальных', 'предпочтений', '.']
# Sentence 15 Words: ['Более', 'добросовестные', 'люди', 'достоверно', 'реже', 'слушают', 'музыку', '.']
# Sentence 16 Words: ['Нейротизм', ',', 'или', 'эмоциональная', 'неустойчивость', ',', 'более', 'характерна', 'для', 'людей', ',', 'прослушивающих', 'музыку', 'печальной', 'и', 'негативной', 'тематики', '.']
# Sentence 17 Words: ['Уровень', 'нейротизма', 'несколько', 'коррелирует', 'со', 'стремлением', 'многократно', 'слушать', 'одно', 'и', 'то', 'же', 'музыкальное', 'произведение', '.']
# Sentence 18 Words: ['Открытость', 'опыту', 'значимо', 'коррелирует', 'с', 'популярной', 'музыкой', 'и', 'современными', 'хитами', '.']
# Sentence 19 Words: ['Низкие', 'показатели', 'открытости', 'опыта', 'наблюдаются', 'у', 'поклонников', 'андеграунда', 'и', 'шансона', '.']
# Sentence 20 Words: ['Верно', 'и', 'обратное', '.']
# Sentence 21 Words: ['С', 'помощью', 'приведенных', 'выше', 'закономерностей', 'на', 'основании', 'типов', 'характеров', 'пользователей', 'возможно', 'сделать', 'вывод', 'об', 'его', 'музыкальных', 'предпочтениях', ',', 'о', 'музыке', ',', 'которая', 'ему', 'будет', 'комфортна', 'и', 'будет', 'им', 'востребована', '.']

# %%
tokenized_text
# Out:
# [['Анализ',
#   'саундтреков',
#   'из',
#   'аккаунтов',
#   'пользователей',
#   'позволяет',
#   'сделать',
#   'выводы',
#   'об',
#   'их',
#   'музыкальных',
#   'предпочтениях',
#   '.'],
#  ['А',
#   'используя',
#   'наработанные',
#   'коррелянты',
#   'можно',
#   'судить',
#   'о',
#   'характере',
#   'пользователя',
#   '.'],
#  ['Например',
#   ',',
#   'считается',
#   ':',
#   'экстраверты',
#   'в',
#   'целом',
#   'чаще',
#   'слушают',
#   'музыку',
#   'и',
#   'их',
#   'музыкальные',
#   'предпочтения',
#   'более',
#   'разнообразны',
#   ',',
#   'однако',
#   'они',
#   'более',
#   'склонны',
#   'к',
#   'поп',
#   ',',
#   'хип-хоп',
#   ',',
#   'сценической',
#   'и',
#   'современной-хитовой',
#   'музыке',
#   '.'],
#  ['Экстраверты',
#   'мало',
#   'слушают',
#   'музыку',
#   ',',
#   'которая',
#   '«',
#   'старше',
#   'их',
#   'по',
#   'возрасту',
#   '»',
#   ':',
#   'т.е',
#   '.'],
#  ['экстраверт',
#   '1990',
#   'года',
#   'рождения',
#   'практически',
#   'не',
#   'будет',
#   'слушать',
#   'музыку',
#   ',',
#   'вышедшую',
#   'раньше',
#   'своего',
#   'рождения',
#   '.'],
#  ['У', 'интровертов', 'это', 'наблюдается', 'в', 'разы', 'чаще', '.'],
#  ['Экстраверты', 'чаще', 'слушают', 'музыку', 'в', 'качестве', 'фона', '.'],
#  ['При',
#   'этом',
#   ',',
#   '-',
#   'доказано',
#   ',',
#   'что',
#   'экстраверты',
#   'по',
#   'сравнению',
#   'с',
#   'интровертами',
#   ',',
#   'чаще',
#   'слушают',
#   'музыку',
#   'со',
#   'словами',
#   ',',
#   'чем',
#   'без',
#   'слов',
#   '.'],
#  ['Интроверты',
#   'практически',
#   'не',
#   'слушают',
#   'современные',
#   'хиты',
#   'из',
#   'топ-10',
#   ',',
#   'а',
#   'начинают',
#   'их',
#   'слушать',
#   '(',
#   'и',
#   'покупать',
#   ')',
#   'спустя',
#   'почти',
#   'год',
#   'после',
#   'их',
#   'выхода',
#   '.'],
#  ['«',
#   'Доброжелательные',
#   '»',
#   'люди',
#   'имеют',
#   'четко',
#   'ограниченный',
#   'набор',
#   'любимых',
#   'песен',
#   'и',
#   'предпочитают',
#   'не',
#   'расширять',
#   'этот',
#   'список',
#   '.'],
#  ['Кстати',
#   ',',
#   'так',
#   'же',
#   'поступают',
#   'и',
#   'люди',
#   'с',
#   'невысокими',
#   'показателями',
#   '«',
#   'открытости',
#   'опыту',
#   '»',
#   '.'],
#  ['Доброжелательные',
#   'люди',
#   'достоверно',
#   'чаще',
#   'предпочитают',
#   'спокойную',
#   ',',
#   'ретро',
#   'и',
#   'релакс-музыку',
#   ',',
#   'а',
#   'менее',
#   'доброжелательные',
#   '–',
#   'панк',
#   'и',
#   'рэп',
#   '.'],
#  ['Удивительно',
#   ',',
#   'но',
#   'шансон',
#   ',',
#   'в',
#   'русском',
#   'понимании',
#   'этого',
#   'направления',
#   ',',
#   'оказался',
#   ',',
#   'что',
#   'больше',
#   'связан',
#   'с',
#   'закрытостью',
#   'к',
#   'опыту',
#   ',',
#   'а',
#   'не',
#   'к',
#   'сниженной',
#   'доброжелательности',
#   '.'],
#  ['«',
#   'Добросовестность',
#   '»',
#   'незначительно',
#   'коррелирует',
#   'с',
#   'хитами',
#   '90-х',
#   'песен',
#   'на',
#   'своем',
#   'языке',
#   ',',
#   'сниженная',
#   'добросовестность',
#   'слабо',
#   'коррелирует',
#   'с',
#   'прослушиванием',
#   'рэпа',
#   'и',
#   'отсутствием',
#   'музыкальных',
#   'предпочтений',
#   '.'],
#  ['Более',
#   'добросовестные',
#   'люди',
#   'достоверно',
#   'реже',
#   'слушают',
#   'музыку',
#   '.'],
#  ['Нейротизм',
#   ',',
#   'или',
#   'эмоциональная',
#   'неустойчивость',
#   ',',
#   'более',
#   'характерна',
#   'для',
#   'людей',
#   ',',
#   'прослушивающих',
#   'музыку',
#   'печальной',
#   'и',
#   'негативной',
#   'тематики',
#   '.'],
#  ['Уровень',
#   'нейротизма',
#   'несколько',
#   'коррелирует',
#   'со',
#   'стремлением',
#   'многократно',
#   'слушать',
#   'одно',
#   'и',
#   'то',
#   'же',
#   'музыкальное',
#   'произведение',
#   '.'],
#  ['Открытость',
#   'опыту',
#   'значимо',
#   'коррелирует',
#   'с',
#   'популярной',
#   'музыкой',
#   'и',
#   'современными',
#   'хитами',
#   '.'],
#  ['Низкие',
#   'показатели',
#   'открытости',
#   'опыта',
#   'наблюдаются',
#   'у',
#   'поклонников',
#   'андеграунда',
#   'и',
#   'шансона',
#   '.'],
#  ['Верно', 'и', 'обратное', '.'],
#  ['С',
#   'помощью',
#   'приведенных',
#   'выше',
#   'закономерностей',
#   'на',
#   'основании',
#   'типов',
#   'характеров',
#   'пользователей',
#   'возможно',
#   'сделать',
#   'вывод',
#   'об',
#   'его',
#   'музыкальных',
#   'предпочтениях',
#   ',',
#   'о',
#   'музыке',
#   ',',
#   'которая',
#   'ему',
#   'будет',
#   'комфортна',
#   'и',
#   'будет',
#   'им',
#   'востребована',
#   '.']]

# %% [markdown]
# ## Text normalization
#
# - Lemmatization, the task of determining that two words have the same root
# - Stemming is a simpler version of lemmatization in which we mainly just strip suffixes from the end of the word

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer

nltk.download('punkt')

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Initialize stemmer and lemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
words = tokenized_text[0]
# Perform stemming
print("Stemming:")
for word in words:
    print(f"{word} -> {stemmer.stem(word)}")
# Out:
# Stemming:
# Анализ -> анализ
# саундтреков -> саундтреков
# из -> из
# аккаунтов -> аккаунтов
# пользователей -> пользователей
# позволяет -> позволяет
# сделать -> сделать
# выводы -> выводы
# об -> об
# их -> их
# музыкальных -> музыкальных
# предпочтениях -> предпочтениях
# . -> .

# %%
# Perform lemmatization (default POS is noun)
print("\nLemmatization:")
for word in words:
    print(f"{word} -> {lemmatizer.lemmatize(word)}")
# Out:
# Lemmatization:
# Анализ -> Анализ
# саундтреков -> саундтреков
# из -> из
# аккаунтов -> аккаунтов
# пользователей -> пользователей
# позволяет -> позволяет
# сделать -> сделать
# выводы -> выводы
# об -> об
# их -> их
# музыкальных -> музыкальных
# предпочтениях -> предпочтениях
# . -> .

# %% [markdown]
# **Вывод**: в моем тексте разницы между лемматизацией и стеммингом нет, после преобразований получаем одни и те же слова.

# %%
## Creating lemmatized text
lemmatized_text = []
for sentence in tokenized_text:
    lemmatized_text.append([lemmatizer.lemmatize(word.lower()) for word in sentence])

lemmatized_text
# Out:
# [['анализ',
#   'саундтреков',
#   'из',
#   'аккаунтов',
#   'пользователей',
#   'позволяет',
#   'сделать',
#   'выводы',
#   'об',
#   'их',
#   'музыкальных',
#   'предпочтениях',
#   '.'],
#  ['а',
#   'используя',
#   'наработанные',
#   'коррелянты',
#   'можно',
#   'судить',
#   'о',
#   'характере',
#   'пользователя',
#   '.'],
#  ['например',
#   ',',
#   'считается',
#   ':',
#   'экстраверты',
#   'в',
#   'целом',
#   'чаще',
#   'слушают',
#   'музыку',
#   'и',
#   'их',
#   'музыкальные',
#   'предпочтения',
#   'более',
#   'разнообразны',
#   ',',
#   'однако',
#   'они',
#   'более',
#   'склонны',
#   'к',
#   'поп',
#   ',',
#   'хип-хоп',
#   ',',
#   'сценической',
#   'и',
#   'современной-хитовой',
#   'музыке',
#   '.'],
#  ['экстраверты',
#   'мало',
#   'слушают',
#   'музыку',
#   ',',
#   'которая',
#   '«',
#   'старше',
#   'их',
#   'по',
#   'возрасту',
#   '»',
#   ':',
#   'т.е',
#   '.'],
#  ['экстраверт',
#   '1990',
#   'года',
#   'рождения',
#   'практически',
#   'не',
#   'будет',
#   'слушать',
#   'музыку',
#   ',',
#   'вышедшую',
#   'раньше',
#   'своего',
#   'рождения',
#   '.'],
#  ['у', 'интровертов', 'это', 'наблюдается', 'в', 'разы', 'чаще', '.'],
#  ['экстраверты', 'чаще', 'слушают', 'музыку', 'в', 'качестве', 'фона', '.'],
#  ['при',
#   'этом',
#   ',',
#   '-',
#   'доказано',
#   ',',
#   'что',
#   'экстраверты',
#   'по',
#   'сравнению',
#   'с',
#   'интровертами',
#   ',',
#   'чаще',
#   'слушают',
#   'музыку',
#   'со',
#   'словами',
#   ',',
#   'чем',
#   'без',
#   'слов',
#   '.'],
#  ['интроверты',
#   'практически',
#   'не',
#   'слушают',
#   'современные',
#   'хиты',
#   'из',
#   'топ-10',
#   ',',
#   'а',
#   'начинают',
#   'их',
#   'слушать',
#   '(',
#   'и',
#   'покупать',
#   ')',
#   'спустя',
#   'почти',
#   'год',
#   'после',
#   'их',
#   'выхода',
#   '.'],
#  ['«',
#   'доброжелательные',
#   '»',
#   'люди',
#   'имеют',
#   'четко',
#   'ограниченный',
#   'набор',
#   'любимых',
#   'песен',
#   'и',
#   'предпочитают',
#   'не',
#   'расширять',
#   'этот',
#   'список',
#   '.'],
#  ['кстати',
#   ',',
#   'так',
#   'же',
#   'поступают',
#   'и',
#   'люди',
#   'с',
#   'невысокими',
#   'показателями',
#   '«',
#   'открытости',
#   'опыту',
#   '»',
#   '.'],
#  ['доброжелательные',
#   'люди',
#   'достоверно',
#   'чаще',
#   'предпочитают',
#   'спокойную',
#   ',',
#   'ретро',
#   'и',
#   'релакс-музыку',
#   ',',
#   'а',
#   'менее',
#   'доброжелательные',
#   '–',
#   'панк',
#   'и',
#   'рэп',
#   '.'],
#  ['удивительно',
#   ',',
#   'но',
#   'шансон',
#   ',',
#   'в',
#   'русском',
#   'понимании',
#   'этого',
#   'направления',
#   ',',
#   'оказался',
#   ',',
#   'что',
#   'больше',
#   'связан',
#   'с',
#   'закрытостью',
#   'к',
#   'опыту',
#   ',',
#   'а',
#   'не',
#   'к',
#   'сниженной',
#   'доброжелательности',
#   '.'],
#  ['«',
#   'добросовестность',
#   '»',
#   'незначительно',
#   'коррелирует',
#   'с',
#   'хитами',
#   '90-х',
#   'песен',
#   'на',
#   'своем',
#   'языке',
#   ',',
#   'сниженная',
#   'добросовестность',
#   'слабо',
#   'коррелирует',
#   'с',
#   'прослушиванием',
#   'рэпа',
#   'и',
#   'отсутствием',
#   'музыкальных',
#   'предпочтений',
#   '.'],
#  ['более',
#   'добросовестные',
#   'люди',
#   'достоверно',
#   'реже',
#   'слушают',
#   'музыку',
#   '.'],
#  ['нейротизм',
#   ',',
#   'или',
#   'эмоциональная',
#   'неустойчивость',
#   ',',
#   'более',
#   'характерна',
#   'для',
#   'людей',
#   ',',
#   'прослушивающих',
#   'музыку',
#   'печальной',
#   'и',
#   'негативной',
#   'тематики',
#   '.'],
#  ['уровень',
#   'нейротизма',
#   'несколько',
#   'коррелирует',
#   'со',
#   'стремлением',
#   'многократно',
#   'слушать',
#   'одно',
#   'и',
#   'то',
#   'же',
#   'музыкальное',
#   'произведение',
#   '.'],
#  ['открытость',
#   'опыту',
#   'значимо',
#   'коррелирует',
#   'с',
#   'популярной',
#   'музыкой',
#   'и',
#   'современными',
#   'хитами',
#   '.'],
#  ['низкие',
#   'показатели',
#   'открытости',
#   'опыта',
#   'наблюдаются',
#   'у',
#   'поклонников',
#   'андеграунда',
#   'и',
#   'шансона',
#   '.'],
#  ['верно', 'и', 'обратное', '.'],
#  ['с',
#   'помощью',
#   'приведенных',
#   'выше',
#   'закономерностей',
#   'на',
#   'основании',
#   'типов',
#   'характеров',
#   'пользователей',
#   'возможно',
#   'сделать',
#   'вывод',
#   'об',
#   'его',
#   'музыкальных',
#   'предпочтениях',
#   ',',
#   'о',
#   'музыке',
#   ',',
#   'которая',
#   'ему',
#   'будет',
#   'комфортна',
#   'и',
#   'будет',
#   'им',
#   'востребована',
#   '.']]

# %%
# Убираем стоп-слова на русском
import nltk
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('russian')
stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %% [markdown]
# ## Build vocabulary

# %%
vocabulary = {}
for sentence in lemmatized_text:
    for word in sentence:
        vocabulary[word] = vocabulary.get(word, 0) + 1

{k: v for k,v in sorted(vocabulary.items(), key=lambda x: x[1], reverse=True)}
# Out:
# {',': 25,
#  '.': 21,
#  'и': 14,
#  'музыку': 7,
#  'с': 7,
#  'слушают': 6,
#  'их': 5,
#  'чаще': 5,
#  'а': 4,
#  'экстраверты': 4,
#  'в': 4,
#  'более': 4,
#  '«': 4,
#  '»': 4,
#  'не': 4,
#  'люди': 4,
#  'коррелирует': 4,
#  'музыкальных': 3,
#  'к': 3,
#  'будет': 3,
#  'слушать': 3,
#  'доброжелательные': 3,
#  'опыту': 3,
#  'из': 2,
#  'пользователей': 2,
#  'сделать': 2,
#  'об': 2,
#  'предпочтениях': 2,
#  'о': 2,
#  ':': 2,
#  'музыке': 2,
#  'которая': 2,
#  'по': 2,
#  'рождения': 2,
#  'практически': 2,
#  'у': 2,
#  'что': 2,
#  'со': 2,
#  'песен': 2,
#  'предпочитают': 2,
#  'же': 2,
#  'открытости': 2,
#  'достоверно': 2,
#  'добросовестность': 2,
#  'хитами': 2,
#  'на': 2,
#  'анализ': 1,
#  'саундтреков': 1,
#  'аккаунтов': 1,
#  'позволяет': 1,
#  'выводы': 1,
#  'используя': 1,
#  'наработанные': 1,
#  'коррелянты': 1,
#  'можно': 1,
#  'судить': 1,
#  'характере': 1,
#  'пользователя': 1,
#  'например': 1,
#  'считается': 1,
#  'целом': 1,
#  'музыкальные': 1,
#  'предпочтения': 1,
#  'разнообразны': 1,
#  'однако': 1,
#  'они': 1,
#  'склонны': 1,
#  'поп': 1,
#  'хип-хоп': 1,
#  'сценической': 1,
#  'современной-хитовой': 1,
#  'мало': 1,
#  'старше': 1,
#  'возрасту': 1,
#  'т.е': 1,
#  'экстраверт': 1,
#  '1990': 1,
#  'года': 1,
#  'вышедшую': 1,
#  'раньше': 1,
#  'своего': 1,
#  'интровертов': 1,
#  'это': 1,
#  'наблюдается': 1,
#  'разы': 1,
#  'качестве': 1,
#  'фона': 1,
#  'при': 1,
#  'этом': 1,
#  '-': 1,
#  'доказано': 1,
#  'сравнению': 1,
#  'интровертами': 1,
#  'словами': 1,
#  'чем': 1,
#  'без': 1,
#  'слов': 1,
#  'интроверты': 1,
#  'современные': 1,
#  'хиты': 1,
#  'топ-10': 1,
#  'начинают': 1,
#  '(': 1,
#  'покупать': 1,
#  ')': 1,
#  'спустя': 1,
#  'почти': 1,
#  'год': 1,
#  'после': 1,
#  'выхода': 1,
#  'имеют': 1,
#  'четко': 1,
#  'ограниченный': 1,
#  'набор': 1,
#  'любимых': 1,
#  'расширять': 1,
#  'этот': 1,
#  'список': 1,
#  'кстати': 1,
#  'так': 1,
#  'поступают': 1,
#  'невысокими': 1,
#  'показателями': 1,
#  'спокойную': 1,
#  'ретро': 1,
#  'релакс-музыку': 1,
#  'менее': 1,
#  '–': 1,
#  'панк': 1,
#  'рэп': 1,
#  'удивительно': 1,
#  'но': 1,
#  'шансон': 1,
#  'русском': 1,
#  'понимании': 1,
#  'этого': 1,
#  'направления': 1,
#  'оказался': 1,
#  'больше': 1,
#  'связан': 1,
#  'закрытостью': 1,
#  'сниженной': 1,
#  'доброжелательности': 1,
#  'незначительно': 1,
#  '90-х': 1,
#  'своем': 1,
#  'языке': 1,
#  'сниженная': 1,
#  'слабо': 1,
#  'прослушиванием': 1,
#  'рэпа': 1,
#  'отсутствием': 1,
#  'предпочтений': 1,
#  'добросовестные': 1,
#  'реже': 1,
#  'нейротизм': 1,
#  'или': 1,
#  'эмоциональная': 1,
#  'неустойчивость': 1,
#  'характерна': 1,
#  'для': 1,
#  'людей': 1,
#  'прослушивающих': 1,
#  'печальной': 1,
#  'негативной': 1,
#  'тематики': 1,
#  'уровень': 1,
#  'нейротизма': 1,
#  'несколько': 1,
#  'стремлением': 1,
#  'многократно': 1,
#  'одно': 1,
#  'то': 1,
#  'музыкальное': 1,
#  'произведение': 1,
#  'открытость': 1,
#  'значимо': 1,
#  'популярной': 1,
#  'музыкой': 1,
#  'современными': 1,
#  'низкие': 1,
#  'показатели': 1,
#  'опыта': 1,
#  'наблюдаются': 1,
#  'поклонников': 1,
#  'андеграунда': 1,
#  'шансона': 1,
#  'верно': 1,
#  'обратное': 1,
#  'помощью': 1,
#  'приведенных': 1,
#  'выше': 1,
#  'закономерностей': 1,
#  'основании': 1,
#  'типов': 1,
#  'характеров': 1,
#  'возможно': 1,
#  'вывод': 1,
#  'его': 1,
#  'ему': 1,
#  'комфортна': 1,
#  'им': 1,
#  'востребована': 1}

# %%
vocabulary["музыку"]
# Out:
# 7

# %%
len(vocabulary.keys())
# Out:
# 203

# %% [markdown]
# ## Byte-pair encoding
#
# - Start with a character-level vocabulary.
#
# - Count the most frequent pair of adjacent symbols (like 't' and 'h' in 'the').
#
# - Merge the most frequent pair into a new symbol ('th').
#
# - Repeat the merge steps for a fixed number of iterations or until no more merges are possible.

# %%
from collections import defaultdict, Counter
from pprint import pprint

#text = "low lower lowest"

# %%
def get_stats(vocab):
    pairs = defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols)-1):
            pairs[(symbols[i], symbols[i+1])] += freq
    return pairs

def merge_vocab(pair, vocab):
    new_vocab = {}
    bigram = ' '.join(pair)
    replacement = ''.join(pair)
    for word in vocab:
        new_word = word.replace(bigram, replacement)
        new_vocab[new_word] = vocab[word]
    return new_vocab

# %%
def byte_pair_encoding(text, num_merges=10):
    words = text.split()
    vocab = {}
    for word in words:
        chars = ' '.join(list(word)) + ' </w>'
        vocab[chars] = vocab.get(chars, 0) + 1

    print("Initial vocabulary:")
    pprint(vocab)

    symbols = set()

    for word in vocab:
        symbols.update(word.split())

    print("Symbols set:", symbols)

    merges = []
    for _ in range(num_merges):
        print("-" * 30)
        pairs = get_stats(vocab)
        print("Pairs:")
        pprint(pairs)
        if not pairs:
            break
        best_pair = max(pairs, key=pairs.get)
        print("Best pair:", best_pair)
        merges.append(best_pair)
        vocab = merge_vocab(best_pair, vocab)
        print("Updated vocabulary:")
        pprint(vocab)
        new_token = ''.join(best_pair)
        symbols.add(new_token)

    # Build final vocabulary: token -> id
    final_vocab = {token: idx for idx, token in enumerate(sorted(symbols))}
    return merges, final_vocab

# %%
text = "муз музыку музыке"
merges, vocab = byte_pair_encoding(text, num_merges=10)
# Out:
# Initial vocabulary:
# {'м у з </w>': 1, 'м у з ы к е </w>': 1, 'м у з ы к у </w>': 1}
# Symbols set: {'</w>', 'ы', 'м', 'е', 'у', 'з', 'к'}
# ------------------------------
# Pairs:
# defaultdict(<class 'int'>,
#             {('е', '</w>'): 1,
#              ('з', '</w>'): 1,
#              ('з', 'ы'): 2,
#              ('к', 'е'): 1,
#              ('к', 'у'): 1,
#              ('м', 'у'): 3,
#              ('у', '</w>'): 1,
#              ('у', 'з'): 3,
#              ('ы', 'к'): 2})
# Best pair: ('м', 'у')
# Updated vocabulary:
# {'му з </w>': 1, 'му з ы к е </w>': 1, 'му з ы к у </w>': 1}
# ------------------------------
# Pairs:
# defaultdict(<class 'int'>,
#             {('е', '</w>'): 1,
#              ('з', '</w>'): 1,
#              ('з', 'ы'): 2,
#              ('к', 'е'): 1,
#              ('к', 'у'): 1,
#              ('му', 'з'): 3,
#              ('у', '</w>'): 1,
#              ('ы', 'к'): 2})
# Best pair: ('му', 'з')
# Updated vocabulary:
# {'муз </w>': 1, 'муз ы к е </w>': 1, 'муз ы к у </w>': 1}
# ------------------------------
# Pairs:
# defaultdict(<class 'int'>,
#             {('е', '</w>'): 1,
#              ('к', 'е'): 1,
#              ('к', 'у'): 1,
#              ('муз', '</w>'): 1,
#              ('муз', 'ы'): 2,
#              ('у', '</w>'): 1,
#              ('ы', 'к'): 2})
# Best pair: ('муз', 'ы')
# Updated vocabulary:
# {'муз </w>': 1, 'музы к е </w>': 1, 'музы к у </w>': 1}
# ------------------------------
# Pairs:
# defaultdict(<class 'int'>,
#             {('е', '</w>'): 1,
#              ('к', 'е'): 1,
#              ('к', 'у'): 1,
#              ('муз', '</w>'): 1,
#              ('музы', 'к'): 2,
#              ('у', '</w>'): 1})
# Best pair: ('музы', 'к')
# Updated vocabulary:
# {'муз </w>': 1, 'музык е </w>': 1, 'музык у </w>': 1}
# ------------------------------
# Pairs:
# defaultdict(<class 'int'>,
#             {('е', '</w>'): 1,
#              ('муз', '</w>'): 1,
#              ('музык', 'е'): 1,
#              ('музык', 'у'): 1,
#              ('у', '</w>'): 1})
# Best pair: ('муз', '</w>')
# Updated vocabulary:
# {'муз</w>': 1, 'музык е </w>': 1, 'музык у </w>': 1}
# ------------------------------
# Pairs:
# defaultdict(<class 'int'>,
#             {('е', '</w>'): 1,
#              ('музык', 'е'): 1,
#              ('музык', 'у'): 1,
#              ('у', '</w>'): 1})
# Best pair: ('музык', 'у')
# Updated vocabulary:
# {'муз</w>': 1, 'музык е </w>': 1, 'музыку </w>': 1}
# ------------------------------
# Pairs:
# defaultdict(<class 'int'>,
#             {('е', '</w>'): 1,
#              ('музык', 'е'): 1,
#              ('музыку', '</w>'): 1})
# Best pair: ('музыку', '</w>')
# Updated vocabulary:
# {'муз</w>': 1, 'музык е </w>': 1, 'музыку</w>': 1}
# ------------------------------
# Pairs:
# defaultdict(<class 'int'>, {('музык', 'е'): 1, ('е', '</w>'): 1})
# Best pair: ('музык', 'е')
# Updated vocabulary:
# {'муз</w>': 1, 'музыке </w>': 1, 'музыку</w>': 1}
# ------------------------------
# Pairs:
# defaultdict(<class 'int'>, {('музыке', '</w>'): 1})
# Best pair: ('музыке', '</w>')
# Updated vocabulary:
# {'муз</w>': 1, 'музыке</w>': 1, 'музыку</w>': 1}
# ------------------------------
# Pairs:
# defaultdict(<class 'int'>, {})

# %%
vocab
# Out:
# {'</w>': 0,
#  'е': 1,
#  'з': 2,
#  'к': 3,
#  'м': 4,
#  'му': 5,
#  'муз': 6,
#  'муз</w>': 7,
#  'музы': 8,
#  'музык': 9,
#  'музыке': 10,
#  'музыке</w>': 11,
#  'музыку': 12,
#  'музыку</w>': 13,
#  'у': 14,
#  'ы': 15}

# %%
## Applying BPE to a list of words
def apply_bpe(word, merges):
    word = list(word) + ['</w>']
    while True:
        pairs = [(word[i], word[i+1]) for i in range(len(word)-1)]
        pair_ranks = {pair: idx for idx, pair in enumerate(merges)}
        ranked = [(pair, pair_ranks[pair]) for pair in pairs if pair in pair_ranks]
        if not ranked:
            break
        best_pair = min(ranked, key=lambda x: x[1])[0]
        new_word = []
        i = 0
        while i < len(word):
            if i < len(word)-1 and (word[i], word[i+1]) == best_pair:
                new_word.append(word[i] + word[i+1])
                i += 2
            else:
                new_word.append(word[i])
                i += 1
        word = new_word
    return word

# %%
print("Vocabulary (token -> id):")
for token, idx in vocab.items():
    print(f"{token}: {idx}")
# Out:
# Vocabulary (token -> id):
# </w>: 0
# е: 1
# з: 2
# к: 3
# м: 4
# му: 5
# муз: 6
# муз</w>: 7
# музы: 8
# музык: 9
# музыке: 10
# музыке</w>: 11
# музыку: 12
# музыку</w>: 13
# у: 14
# ы: 15

# %%
# Tokenize and convert to token IDs
new_text = "machine machines"
token_ids = []
for word in text.strip().split():
    bpe_tokens = apply_bpe(word, merges)
    ids = [vocab[token] for token in bpe_tokens if token in vocab]
    token_ids.extend(ids)
print("\nToken IDs:")
print(token_ids)
# Out:
# Token IDs:
# [7, 13, 11]
